# %%
import pandas as pd
import matplotlib.pyplot as plt
import chardet
import numpy as np
import matplotlib.pyplot as plt
with open('Sample_Superstore 2.csv', 'rb') as f:
    encoding = chardet.detect(f.read())['encoding']
df = pd.read_csv('Sample_Superstore 2.csv',encoding=encoding)
df.head(10)
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       3  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 5       6  CA-2014-115812    6/9/2014   6/14/2014  Standard Class    BH-11710
# 6       7  CA-2014-115812    6/9/2014   6/14/2014  Standard Class    BH-11710
# 7       8  CA-2014-115812    6/9/2014   6/14/2014  Standard Class    BH-11710
# 8       9  CA-2014-115812    6/9/2014   6/14/2014  Standard Class    BH-11710
# 9      10  CA-2014-115812    6/9/2014   6/14/2014  Standard Class    BH-11710
#
#      Customer Name    Segment        Country             City  ...  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   object
#  2   Order Date     9994 non-null   object
#  3   Ship Date      9994 non-null   object
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
# ...

# %%
df.shape
# Out:
# (9994, 21)

# %%
df.isnull()
# Out:
#       Row ID  Order ID  Order Date  Ship Date  Ship Mode  Customer ID  \
# 0      False     False       False      False      False        False
# 1      False     False       False      False      False        False
# 2      False     False       False      False      False        False
# 3      False     False       False      False      False        False
# 4      False     False       False      False      False        False
# ...      ...       ...         ...        ...        ...          ...
# 9989   False     False       False      False      False        False
# 9990   False     False       False      False      False        False
# 9991   False     False       False      False      False        False
# 9992   False     False       False      False      False        False
# 9993   False     False       False      False      False        False
#
#       Customer Name  Segment  Country   City  ...  Postal Code  Region  \
# ...

# %%
df.sample()
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 2658    2659  CA-2016-150343  8/16/2016  8/20/2016  Standard Class
#
#      Customer ID Customer Name   Segment        Country           City  ...  \
# 2658    PK-19075     Pete Kriz  Consumer  United States  San Francisco  ...
#
#      Postal Code  Region       Product ID         Category Sub-Category  \
# 2658       94110    West  OFF-EN-10004030  Office Supplies    Envelopes
#
#                                  Product Name  Sales  Quantity  Discount  \
# 2658  Convenience Packs of Business Envelopes  10.86         3       0.0
#
#       Profit
# 2658  5.1042
#
# [1 rows x 21 columns]

# %%
df.nlargest(10,'Quantity')
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 113      114  CA-2014-115259   8/25/2014   8/27/2014    Second Class
# 139      140  CA-2016-145583  10/13/2016  10/19/2016  Standard Class
# 575      576  CA-2015-149713   9/18/2015   9/22/2015    Second Class
# 660      661  CA-2015-146563   8/24/2015   8/28/2015  Standard Class
# 1045    1046  CA-2017-152702  10/12/2017  10/16/2017  Standard Class
# 1363    1364  US-2017-155425  11/10/2017  11/11/2017     First Class
# 1429    1430  US-2015-164448  10/31/2015   11/4/2015    Second Class
# 1433    1434  CA-2014-120768  12/19/2014  12/21/2014    Second Class
# 1711    1712  CA-2017-123491  10/30/2017   11/5/2017  Standard Class
# 2793    2794  CA-2014-154599   4/12/2014   4/17/2014  Standard Class
#
#      Customer ID      Customer Name      Segment        Country  \
# 113     RC-19960         Ryan Crowe     Consumer  United States
# 139     LC-16885     Lena Creighton     Consumer  United States
# ...

# %%
duplicates=df.duplicated().sum()
duplicates
# Out:
# 0

# %%
df['Category'].unique()
# Out:
# array(['Furniture', 'Office Supplies', 'Technology'], dtype=object)

# %%
profit_df = df[df['Profit']>0]
profit_df
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0          1  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 1          2  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 2          3  CA-2016-138688   6/12/2016   6/16/2016    Second Class
# 4          5  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# 5          6  CA-2014-115812    6/9/2014   6/14/2014  Standard Class
# ...      ...             ...         ...         ...             ...
# 9989    9990  CA-2014-110422   1/21/2014   1/23/2014    Second Class
# 9990    9991  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9991    9992  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9992    9993  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9993    9994  CA-2017-119914    5/4/2017    5/9/2017    Second Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# ...

# %%
df.groupby(by='Segment').sum()
# Out:
#                Row ID                                           Order ID  \
# Segment
# Consumer     25581329  CA-2016-152156CA-2016-152156US-2015-108966US-2...
# Corporate    15504734  CA-2016-138688CA-2016-137330CA-2016-137330CA-2...
# Home Office   8858952  US-2015-118983US-2015-118983CA-2017-107727CA-2...
#
#                                                     Order Date  \
# Segment
# Consumer     11/8/201611/8/201610/11/201510/11/20156/9/2014...
# Corporate    6/12/201612/9/201612/9/201612/8/201612/8/20169...
# Home Office  11/22/201511/22/201510/19/201712/27/201512/27/...
#
#                                                      Ship Date  \
# Segment
# Consumer     11/11/201611/11/201610/18/201510/18/20156/14/2...
# Corporate    6/16/201612/13/201612/13/201612/10/201612/10/2...
# Home Office  11/26/201511/26/201510/23/201712/31/201512/31/...
#
#                                                      Ship Mode  \
# Segment
# ...

# %%
loss_df = df[df['Profit']<0]
loss_df
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 3          4  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# 14        15  US-2015-118983  11/22/2015  11/26/2015  Standard Class
# 15        16  US-2015-118983  11/22/2015  11/26/2015  Standard Class
# 23        24  US-2017-156909   7/16/2017   7/18/2017    Second Class
# 27        28  US-2015-150630   9/17/2015   9/21/2015  Standard Class
# ...      ...             ...         ...         ...             ...
# 9920    9921  CA-2016-149272   3/15/2016   3/19/2016  Standard Class
# 9921    9922  CA-2014-111360  11/24/2014  11/30/2014  Standard Class
# 9931    9932  CA-2015-104948  11/13/2015  11/17/2015  Standard Class
# 9937    9938  CA-2016-164889    6/3/2016    6/6/2016    Second Class
# 9962    9963  CA-2015-168088   3/19/2015   3/22/2015     First Class
#
#      Customer ID     Customer Name      Segment        Country  \
# 3       SO-20335    Sean O'Donnell     Consumer  United States
# ...

# %%
loss_df.describe()
# Out:
#             Row ID   Postal Code         Sales     Quantity     Discount  \
# count  1871.000000   1871.000000   1871.000000  1871.000000  1871.000000
# mean   5123.965794  55991.122929    250.511574     3.762694     0.480887
# std    2929.381441  26041.501999    715.067296     2.141347     0.235080
# min       4.000000   1841.000000      0.444000     1.000000     0.100000
# 25%    2599.000000  33024.000000     12.503000     2.000000     0.200000
# 50%    5098.000000  60623.000000     71.088000     3.000000     0.400000
# 75%    7788.000000  77095.000000    284.922000     5.000000     0.700000
# max    9963.000000  98198.000000  22638.480000    14.000000     0.800000
#
#             Profit
# count  1871.000000
# mean    -83.448042
# std     284.423422
# min   -6599.978000
# 25%     -58.660950
# 50%     -18.088200
# 75%      -6.261500
# max      -0.089500

# %%
loss_df.groupby(by='Segment').sum()
# Out:
#               Row ID                                           Order ID  \
# Segment
# Consumer     5101571  US-2015-108966US-2017-156909US-2015-150630US-2...
# Corporate    2927896  CA-2016-117590US-2017-118038US-2017-118038US-2...
# Home Office  1557473  US-2015-118983US-2015-118983CA-2015-117415CA-2...
#
#                                                     Order Date  \
# Segment
# Consumer     10/11/20157/16/20179/17/20159/17/20159/17/2015...
# Corporate    12/8/201612/9/201712/9/20174/5/20152/2/20179/1...
# Home Office  11/22/201511/22/201512/27/201512/27/20154/30/2...
#
#                                                      Ship Date  \
# Segment
# Consumer     10/18/20157/18/20179/21/20159/21/20159/21/2015...
# Corporate    12/10/201612/11/201712/11/20174/10/20152/5/201...
# Home Office  11/26/201511/26/201512/31/201512/31/20155/5/20...
#
#                                                      Ship Mode  \
# Segment
# ...

# %%
loss_df.shape
# Out:
# (1871, 21)

# %%
loss_df.groupby(by='Sub-Category').sum()
# Out:
#                Row ID                                           Order ID  \
# Sub-Category
# Accessories    499173  CA-2016-158568US-2015-156867US-2017-100930US-2...
# Appliances     355294  US-2015-118983CA-2014-139892US-2014-100853US-2...
# Binders       3081543  US-2015-118983US-2015-150630US-2015-150630US-2...
# Bookcases      577022  US-2015-150630CA-2015-117415CA-2015-146262CA-2...
# Chairs        1235400  US-2017-156909CA-2015-117415US-2015-164175US-2...
# Fasteners       61455  CA-2015-161263CA-2015-105221CA-2017-133648CA-2...
# Furnishings    906096  CA-2016-117590US-2017-118038US-2014-147606US-2...
# Machines       209526  CA-2014-139892CA-2015-146262CA-2015-169397US-2...
# Phones         695295  US-2017-164147CA-2015-146262US-2016-141544US-2...
# Storage        819663  US-2015-134026US-2017-119662CA-2014-139892US-2...
# Supplies       149266  US-2015-101511CA-2016-112697CA-2016-109869US-2...
# Tables         997207  US-2015-108966US-2014-134614CA-2014-133690US-2...
#
# ...

# %%
loss_df.groupby(by='City').sum(). sort_values('Profit',ascending=True)
# Out:
#                Row ID                                           Order ID  \
# City
# Philadelphia  1209769  US-2017-156909US-2015-150630US-2015-150630US-2...
# Houston        985125  CA-2015-117415CA-2015-117415US-2017-118038US-2...
# Chicago        769944  US-2015-164175US-2017-119662CA-2016-158568CA-2...
# San Antonio    172970  CA-2014-139892CA-2014-139892CA-2014-139892CA-2...
# Lancaster      125296  CA-2014-136742US-2017-111024CA-2017-121839CA-2...
# ...               ...                                                ...
# Loveland        11182                       CA-2017-156720US-2017-162068
# Pensacola        4879                                     US-2016-131891
# Elyria           8716                                     CA-2017-121678
# Homestead        3947                                     CA-2017-167871
# Coppell          1497                                     CA-2017-152485
#
#                                                      Order Date  \
# City
# ...

# %%
loss_df.sort_values(['Sales'],ascending=True).groupby(by='Category')

# %%
Total_loss=np.negative(loss_df['Profit'].sum())
print("Total loss = %.2f" %Total_loss)
# Out:
# Total loss = 156131.29

# %%
plt.rcParams['figure.figsize']= (10,5)

# %%
plt.bar (loss_df['Sub-Category'],loss_df['Sales'])
plt.rcParams.update({'font.size':10})
plt.xlabel('Sub_Cateroty')
plt.ylabel('Sales')
# Out:
# Text(0, 0.5, 'Sales')

# %%
plt.rcParams['figure.figsize']=(18,8)
plt.bar(df['Sub-Category'],df['Sales'])
plt.rcParams.update({'font.size':14})
plt.xlabel('Sub_Category')
plt.ylabel('Sales')
# Out:
# Text(0, 0.5, 'Sales')

# %%
plt.rcParams['figure.figsize']=(18,8)
plt.bar(df['Sub-Category'],df['Discount'])
plt.rcParams.update({'font.size':14})
plt.xlabel('Sub_Category')
plt.ylabel('Discount')
# Out:
# Text(0, 0.5, 'Discount')

# %%
import seaborn as sns
sns.pairplot(df,hue='Quantity',height=2.5)

# %%
sns.catplot(x="Ship Mode",y="Sales",kind="violin",data=df)
